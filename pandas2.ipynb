# %%
import pandas as pd

# %%
ipl = pd.read_csv('matches.csv')

# %%
ipl.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  05/04/17          Sunrisers Hyderabad
# 1   2    2017       Pune  06/04/17               Mumbai Indians
# 2   3    2017     Rajkot  07/04/17                Gujarat Lions
# 3   4    2017     Indore  08/04/17       Rising Pune Supergiant
# 4   5    2017  Bangalore  08/04/17  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
ipl.tail()
# Out:
#       id  season       city      date                team1  \
# 631  632    2016     Raipur  22/05/16     Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16        Gujarat Lions
# 633  634    2016      Delhi  25/05/16  Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16        Gujarat Lions
# 635  636    2016  Bangalore  29/05/16  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
#importing from github 
ipl = pd.read_csv('https://raw.githubusercontent.com/training-ml/Files/main/matches.csv')
ipl.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  05/04/17          Sunrisers Hyderabad
# 1   2    2017       Pune  06/04/17               Mumbai Indians
# 2   3    2017     Rajkot  07/04/17                Gujarat Lions
# 3   4    2017     Indore  08/04/17       Rising Pune Supergiant
# 4   5    2017  Bangalore  08/04/17  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
ipl.shape
# Out:
# (636, 18)

# %%
ipl.sample(n=7)
# Out:
#       id  season       city      date                        team1  \
# 361  362    2012       Pune  11/05/12  Royal Challengers Bangalore
# 51    52    2017     Kanpur  13/05/17                Gujarat Lions
# 233  234    2010     Mumbai  25/04/10          Chennai Super Kings
# 401  402    2013       Pune  17/04/13          Sunrisers Hyderabad
# 322  323    2012      Delhi  19/04/12              Deccan Chargers
# 452  453    2013  Hyderabad  19/05/13        Kolkata Knight Riders
# 0      1    2017  Hyderabad  05/04/17          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 361                Pune Warriors                Pune Warriors         field
# 51           Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 233               Mumbai Indians          Chennai Super Kings           bat
# 401                Pune Warriors                Pune Warriors         field
# ...

# %%
type(ipl)
# Out:
# pandas.core.frame.DataFrame

# %%
#Importing excel file
excel_file = pd.read_excel(r'C:\Users\shail\Desktop\Lead.xlsx',sheet_name='Sheet1')
excel_file
# Out:
#    Agreement Expiry Detail                     Unnamed: 1  Unnamed: 2  \
# 0                      NaN                            NaN         NaN
# 1             CustomerCode                   CustomerName    SchoolId
# 2               TECE003586      Gurukul Vidyapeeth Khekra  ESCH010195
# 3               TECE000894             C.f Andrews School  ESCH017200
# 4               TECE012878   Smart Business Incorporation  ESCH023322
# ..                     ...                            ...         ...
# 60              TECE006023          Suditi Global Academy  ESCH019399
# 61              TECE003494  Mihi Lal Baghel Public School  ESCH018344
# 62              TECE002940            Rajiv International  ESCH008623
# 63              TECE005343   Shanti Niketan Public School  ESCH018900
# 64              TEHW000870                     M S School  ESCH018392
#
#                             Unnamed: 3     Unnamed: 4       Unnamed: 5  \
# ...

# %%
#Exporting Data to current folder
ipl.to_csv('ipl_cleanup.csv')

# %%
#Exporting to different folder
ipl.to_csv(r'C:\Users\shail\Desktop\W\ipl_cleanup.csv',index=False, header=True)
